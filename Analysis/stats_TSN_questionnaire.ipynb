# %% [markdown]
# # Questionnaire processing
#
# The purpose of this code is to retrieve the questionnaire data and export it to a cleaned CSV. We will use this CSV file in our scripts to compare the questoinnaire results.

# %% [markdown]
# ## Load necessary packages

# %%
import pandas as pd
import numpy as np
import glob
import statsmodels

# %% [markdown]
# ## Read in .csv data

# %%
sample = pd.read_csv('../Data/quest_raw/Participant_5_TSN_PostQ_Feb_13_2020_2021_Dec_08_1302.csv',
           usecols=['itemIndex', 'questions', 'ratings'],
           skiprows=[1,26])

# %%
questions = sample.questions

# %%
df = pd.DataFrame(columns=sample['itemIndex'])

for f in glob.glob('../Data/quest_raw/Part*.csv'):
    df = df.append([pd.read_csv(f, usecols = ['questions','ratings'], skiprows = [1,26])['ratings']], ignore_index=True)

# %%
df = df.drop(labels=[24], axis=1)

# %% [markdown]
# ## Data Cleaning
# ### Replace columns

# %%
dat = df.rename(columns={
    0: 'gender',
    1: 'skill',
    2: 'hand',
    3: 'english_first',
    4: 'risk_appetite_1',
    5: 'risk_appetite_2',
    6: 'threat_susceptibility_1',
    7: 'risk_appetite_3',
    8: 'risk_appetite_4',
    9: 'malware_risk_1',
    10:'threat_severity_1',
    11:'malware_risk_2',
    12:'threat_severity_2',
    13:'malware_risk_3',
    14:'threat_susceptibility_2',
    15:'threat_severity_3',
    16:'risk_appetite_5',
    17:'risk_appetite_6',
    18:'threat_susceptibility_3',
    19:'have_antivirus',
    20:'updated_antivirus',
    21:'updated_os',
    22:'check_computer',
    23:'have_firewall',
    
})

# %% [markdown]
# ### Add Participant Numbers

# %%
dat['subject'] = ['Participant_4',
                  'Participant_5',
                  'Participant_6',
                  'Participant_7',
                  'Participant_8',
                  'Participant_9',
                  'Participant_10',
                  'Participant_11',
                  'Participant_12',
                  'Participant_13',
                  'Participant_14',
                  'Participant_15',
                  'Participant_16',
                  'Participant_17',
                  'Participant_18',
                  'Participant_19',
                  'Participant_20',
                  'Participant_21',
                  'Participant_22',
                  'Participant_23',
                  'Participant_24'
                 ]

# %% [markdown]
# ### Change to variables

# %%
dat['skill'] = dat['skill'].replace(['not at all', 
                                   'almost not at all', 
                                   'very little', 
                                   'neutral', 
                                   'a bit',
                                   'very much',
                                   'extremely'], [1,2,3,4,5,6,7])

dat['risk_appetite_2'] = dat['risk_appetite_2'].replace(['very easy',
                                                         'easy',
                                                         'neither easy or difficult',
                                                         'difficult',
                                                         'very difficult'], [1,2,3,4,5])


dat = dat.replace(['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree'], [1,2,3,4,5])

dat['risk_appetite_1'] = dat['risk_appetite_1'].astype(int)

# %% [markdown]
# ### Add ages
# These are manually assigned because it is very painful to convert from PsychoPy's format for recording number key inputs. Everything else is much easier. These values can be retrieved manually from each of the PsychoPy questionnaire files.

# %%
dat['age'] = [26,25,25,25,23,20,26,20,21,18,20,20,20,20,21,18,28,21,28,21,20]

# %% [markdown]
# ### Sort columns alphabetically

# %%
dat = dat.sort_index(axis=1, ascending=True)
dat.head()
# Out:
#    age check_computer english_first  gender   hand have_antivirus  \
# 0   26            yes           yes  female  right            yes
# 1   25            yes            no    male  right            yes
# 2   25             no           yes  female  right             no
# 3   25             no            no  female  right             no
# 4   23             no           yes  female  right             no
#
#   have_firewall  malware_risk_1  malware_risk_2  malware_risk_3  ...  skill  \
# 0           yes               5               5               5  ...      6
# 1           yes               4               4               4  ...      6
# 2            no               4               2               2  ...      5
# 3            no               5               5               5  ...      5
# 4            no               4               3               4  ...      4
#
#          subject  threat_severity_1  threat_severity_2  threat_severity_3  \
# 0  Participant_4                  5                  5                  5
# 1  Participant_5                  5                  5                  5
# 2  Participant_6                  3                  3                  2
# 3  Participant_7                  4                  4                  4
# 4  Participant_8                  4                  4                  4
#
#    threat_susceptibility_1  threat_susceptibility_2 threat_susceptibility_3  \
# 0                        5                        5                       5
# 1                        3                        3                       3
# 2                        3                        3                       2
# 3                        2                        4                       2
# 4                        3                        4                       2
#
#    updated_antivirus  updated_os
# 0                yes         yes
# 1                yes         yes
# 2                 no          no
# 3                 no          no
# 4                 no          no
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Descriptive statistics

# %%
dat.describe()
# Out:
#              age  malware_risk_1  malware_risk_2  malware_risk_3  \
# count  21.000000       21.000000       21.000000       21.000000
# mean   22.190476        3.952381        3.523810        3.857143
# std     3.124405        0.589592        0.980767        0.654654
# min    18.000000        2.000000        2.000000        2.000000
# 25%    20.000000        4.000000        3.000000        4.000000
# 50%    21.000000        4.000000        4.000000        4.000000
# 75%    25.000000        4.000000        4.000000        4.000000
# max    28.000000        5.000000        5.000000        5.000000
#
#        risk_appetite_1  risk_appetite_2  risk_appetite_3  risk_appetite_4  \
# count        21.000000        21.000000        21.000000        21.000000
# mean          4.476190         3.190476         3.952381         2.952381
# std           1.209093         0.749603         1.071270         0.864650
# min           2.000000         2.000000         1.000000         2.000000
# 25%           4.000000         3.000000         4.000000         2.000000
# 50%           5.000000         3.000000         4.000000         3.000000
# 75%           5.000000         4.000000         5.000000         4.000000
# max           7.000000         4.000000         5.000000         4.000000
#
#        risk_appetite_5  risk_appetite_6      skill  threat_severity_1  \
# count        21.000000        21.000000  21.000000          21.000000
# mean          3.238095         2.380952   4.952381           3.761905
# std           0.995227         0.864650   1.203170           0.830949
# min           2.000000         1.000000   1.000000           2.000000
# 25%           2.000000         2.000000   5.000000           3.000000
# 50%           3.000000         2.000000   5.000000           4.000000
# 75%           4.000000         3.000000   6.000000           4.000000
# max           5.000000         4.000000   6.000000           5.000000
#
#        threat_severity_2  threat_severity_3  threat_susceptibility_1  \
# count          21.000000          21.000000                21.000000
# mean            3.619048           3.238095                 2.666667
# std             0.804748           0.943650                 0.912871
# min             2.000000           2.000000                 1.000000
# 25%             3.000000           3.000000                 2.000000
# 50%             4.000000           3.000000                 3.000000
# 75%             4.000000           4.000000                 3.000000
# max             5.000000           5.000000                 5.000000
#
#        threat_susceptibility_2  threat_susceptibility_3
# count                21.000000                21.000000
# mean                  3.523810                 2.619048
# std                   0.980767                 0.920662
# min                   1.000000                 2.000000
# 25%                   3.000000                 2.000000
# 50%                   4.000000                 2.000000
# 75%                   4.000000                 3.000000
# max                   5.000000                 5.000000

# %%
dat
# Out:
#     age check_computer english_first  gender   hand have_antivirus  \
# 0    26            yes           yes  female  right            yes
# 1    25            yes            no    male  right            yes
# 2    25             no           yes  female  right             no
# 3    25             no            no  female  right             no
# 4    23             no           yes  female  right             no
# 5    20             no            no    male  right             no
# 6    26            yes           yes  female  right            yes
# 7    20             no           yes  female  right             no
# 8    21             no            no  female  right             no
# 9    18             no           yes  female  right             no
# 10   20             no           yes  female  right            yes
# 11   20             no           yes  female   left             no
# 12   20            yes           yes  female  right            yes
# 13   20             no           yes    male  right            yes
# 14   21            yes           yes    male  right            yes
# 15   18             no           yes  female  right            yes
# 16   28             no           yes    male  right             no
# 17   21             no           yes  female  right             no
# 18   28             no            no  female  right             no
# 19   21             no            no  female  right            yes
# 20   20             no           yes  female  right            yes
#
#    have_firewall  malware_risk_1  malware_risk_2  malware_risk_3  ...  skill  \
# 0            yes               5               5               5  ...      6
# 1            yes               4               4               4  ...      6
# 2             no               4               2               2  ...      5
# 3             no               5               5               5  ...      5
# 4             no               4               3               4  ...      4
# 5             no               4               4               4  ...      5
# 6            yes               4               2               4  ...      6
# 7            yes               3               4               4  ...      5
# 8             no               4               3               4  ...      6
# 9             no               4               4               3  ...      5
# 10            no               4               2               4  ...      3
# 11            no               4               4               4  ...      5
# 12           yes               4               3               4  ...      5
# 13            no               4               4               4  ...      6
# 14           yes               4               4               4  ...      6
# 15           yes               4               3               4  ...      1
# 16            no               4               4               4  ...      5
# 17            no               4               3               3  ...      5
# 18           yes               2               2               3  ...      6
# 19           yes               4               5               4  ...      5
# 20           yes               4               4               4  ...      4
#
#            subject  threat_severity_1  threat_severity_2  threat_severity_3  \
# 0    Participant_4                  5                  5                  5
# 1    Participant_5                  5                  5                  5
# 2    Participant_6                  3                  3                  2
# 3    Participant_7                  4                  4                  4
# 4    Participant_8                  4                  4                  4
# 5    Participant_9                  4                  4                  2
# 6   Participant_10                  4                  4                  3
# 7   Participant_11                  2                  2                  2
# 8   Participant_12                  4                  4                  3
# 9   Participant_13                  4                  3                  3
# 10  Participant_14                  5                  4                  4
# 11  Participant_15                  4                  4                  4
# 12  Participant_16                  3                  4                  4
# 13  Participant_17                  2                  2                  2
# 14  Participant_18                  4                  3                  3
# 15  Participant_19                  3                  3                  3
# 16  Participant_20                  3                  3                  2
# 17  Participant_21                  4                  4                  3
# 18  Participant_22                  4                  4                  4
# 19  Participant_23                  4                  4                  3
# 20  Participant_24                  4                  3                  3
#
#     threat_susceptibility_1  threat_susceptibility_2 threat_susceptibility_3  \
# 0                         5                        5                       5
# 1                         3                        3                       3
# 2                         3                        3                       2
# 3                         2                        4                       2
# 4                         3                        4                       2
# 5                         2                        2                       2
# 6                         2                        4                       4
# 7                         2                        3                       2
# 8                         3                        4                       2
# 9                         3                        4                       4
# 10                        3                        4                       2
# 11                        2                        2                       2
# 12                        2                        4                       3
# 13                        2                        4                       4
# 14                        3                        3                       2
# 15                        2                        4                       3
# 16                        4                        4                       2
# 17                        2                        5                       2
# 18                        1                        1                       2
# 19                        4                        4                       3
# 20                        3                        3                       2
#
#     updated_antivirus  updated_os
# 0                 yes         yes
# 1                 yes         yes
# 2                  no          no
# 3                  no          no
# 4                  no          no
# 5                  no         yes
# 6                 yes          no
# 7                  no         yes
# 8                  no          no
# 9                  no          no
# 10                 no          no
# 11                 no          no
# 12                yes         yes
# 13                 no         yes
# 14                yes         yes
# 15                 no          no
# 16                 no         yes
# 17                 no          no
# 18                 no          no
# 19                 no         yes
# 20                yes          no
#
# [21 rows x 26 columns]

# %%
dat = dat.drop(dat.index[8]) # remove participant 12 as they were removed from analysis

# %% [markdown]
# ### Demographics

# %%
dat['gender'].value_counts()
# Out:
# female    15
# male       5
# Name: gender, dtype: int64

# %%
dat['hand'].value_counts()
# Out:
# right    19
# left      1
# Name: hand, dtype: int64

# %%
dat['english_first'].value_counts()
# Out:
# yes    15
# no      5
# Name: english_first, dtype: int64

# %% [markdown]
# ### Characteristics

# %%
dat['have_antivirus'].value_counts()
# Out:
# yes    10
# no     10
# Name: have_antivirus, dtype: int64

# %%
dat['updated_antivirus'].value_counts()
# Out:
# no     14
# yes     6
# Name: updated_antivirus, dtype: int64

# %%
dat['updated_os'].value_counts()
# Out:
# no     11
# yes     9
# Name: updated_os, dtype: int64

# %%
dat['check_computer'].value_counts()
# Out:
# no     15
# yes     5
# Name: check_computer, dtype: int64

# %%
dat['have_firewall'].value_counts()
# Out:
# yes    10
# no     10
# Name: have_firewall, dtype: int64

# %% [markdown]
# ### Preparing instruments

# %%
dat.columns
# Out:
# Index(['age', 'check_computer', 'english_first', 'gender', 'hand',
#        'have_antivirus', 'have_firewall', 'malware_risk_1', 'malware_risk_2',
#        'malware_risk_3', 'risk_appetite_1', 'risk_appetite_2',
#        'risk_appetite_3', 'risk_appetite_4', 'risk_appetite_5',
#        'risk_appetite_6', 'skill', 'subject', 'threat_severity_1',
#        'threat_severity_2', 'threat_severity_3', 'threat_susceptibility_1',
#        'threat_susceptibility_2', 'threat_susceptibility_3',
#        'updated_antivirus', 'updated_os'],
#       dtype='object')

# %%
dat['malware_risk'] = (dat['malware_risk_1'] + dat['malware_risk_2'] + dat['malware_risk_3'])/3
dat['risk_appetite'] = (dat['risk_appetite_1'] + dat['risk_appetite_2'] + dat['risk_appetite_3'] + dat['risk_appetite_4'] + dat['risk_appetite_5'] + dat['risk_appetite_6'])/6
dat['threat_severity'] = (dat['threat_severity_1'] + dat['threat_severity_2'] + dat['threat_severity_3'])/3
dat['threat_susceptibility'] = (dat['threat_susceptibility_1'] + dat['threat_susceptibility_2'] + dat['threat_susceptibility_3'])/3

# %%
dat_processed = dat[['subject','check_computer', 'english_first', 'gender', 'hand', 'have_antivirus', 'have_firewall', 'updated_antivirus', 'updated_os', 'malware_risk', 'risk_appetite', 'threat_severity', 'threat_susceptibility']]

# %%
dat_processed.head()
# Out:
#          subject check_computer english_first  gender   hand have_antivirus  \
# 0  Participant_4            yes           yes  female  right            yes
# 1  Participant_5            yes            no    male  right            yes
# 2  Participant_6             no           yes  female  right             no
# 3  Participant_7             no            no  female  right             no
# 4  Participant_8             no           yes  female  right             no
#
#   have_firewall updated_antivirus updated_os  malware_risk  risk_appetite  \
# 0           yes               yes        yes      5.000000       4.000000
# 1           yes               yes        yes      4.000000       2.500000
# 2            no                no         no      2.666667       3.166667
# 3            no                no         no      5.000000       2.500000
# 4            no                no         no      3.666667       3.666667
#
#    threat_severity  threat_susceptibility
# 0         5.000000               5.000000
# 1         5.000000               3.000000
# 2         2.666667               2.666667
# 3         4.000000               2.666667
# 4         4.000000               3.000000

# %% [markdown]
# ### Write to CSV

# %%
dat_processed.to_csv('./questionaires.csv')
